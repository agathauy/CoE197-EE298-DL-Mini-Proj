# %%
import seaborn
import librosa
import numpy as np


CONTENT_FILENAME = "inputs/treasure_10.mp3"
audio_filename = CONTENT_FILENAME
#audio_filename = './data/369148__flying-deer-fx__music-box-the-flea-waltz.wav'

#sr = 8000
y, sr = librosa.load(audio_filename, sr=None, mono=True)
print y.shape

min_y = np.min(y)
max_y = np.max(y)

# normalize
y = (y - min_y) / (max_y - min_y)
print y.dtype, min_y, max_y

from IPython.display import Audio
Audio(y, rate=sr)
# Out:
#   File "<ipython-input-1-8e58cc836784>", line 12
#     print y.shape
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(y.shape)?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(30,5))
plt.plot(y[20000:20128].transpose())
plt.show()

# %%
# Build a model
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.layers import Input
from keras.optimizers import RMSprop
import tensorflow as tf

# so try to estimate next sample afte given (maxlen) samples
maxlen     = 128 # 128 / sr = 0.016 sec
nb_output = 256  # resolution - 8bit encoding
latent_dim = 128 

inputs = Input(shape=(maxlen, nb_output))
x = LSTM(latent_dim, return_sequences=True)(inputs)
x = Dropout(0.4)(x)
x = LSTM(latent_dim)(x)
x = Dropout(0.4)(x)
output = Dense(nb_output, activation='softmax')(x)
model = Model(inputs, output)

#optimizer = Adam(lr=0.005)
optimizer = RMSprop(lr=0.01) 
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
from tqdm import tqdm

# try to estimate next_sample (0 -255) based on 256 previous samples 
step = 5
next_sample = []
samples = []
for j in tqdm(range(0, y.shape[0] - maxlen, step)):
    seq = y[j: j + maxlen + 1]  
    seq_matrix = np.zeros((maxlen, nb_output), dtype=bool) 
    for i,s in enumerate(seq):
        sample_ = int(s * (nb_output - 1)) # 0-255
        if i < maxlen:
            seq_matrix[i, sample_] = True
        else:
            seq_vec = np.zeros(nb_output, dtype=bool)
            seq_vec[sample_] = True
            next_sample.append(seq_vec)
    samples.append(seq_matrix)
samples = np.array(samples, dtype=bool)
next_sample = np.array(next_sample, dtype=bool)
print samples.shape, next_sample.shape
# Out:
# 100%|██████████| 44438/44438 [00:10<00:00, 4082.20it/s]
# (44438, 128, 256) (44438, 256)

# %%
from keras.callbacks import EarlyStopping, CSVLogger, ModelCheckpoint
csv_logger = CSVLogger('training_audio.log')
escb = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
checkpoint = ModelCheckpoint("models/audio-{epoch:02d}-{val_loss:.2f}.hdf5", monitor='val_loss', verbose=1, period=2)

model.fit(samples, next_sample, shuffle=True, batch_size=256, verbose=1, #initial_epoch=50,
          validation_split=0.1, nb_epoch=500, callbacks=[csv_logger, escb, checkpoint])
# Out:
# Train on 39994 samples, validate on 4444 samples
# Epoch 1/500
# 39994/39994 [==============================] - 58s - loss: 4.7196 - val_loss: 3.4106
# Epoch 2/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 4.3905Epoch 00001: saving model to models/audio-01-2.84.hdf5
# 39994/39994 [==============================] - 57s - loss: 4.3903 - val_loss: 2.8432
# Epoch 3/500
# 39994/39994 [==============================] - 56s - loss: 4.0887 - val_loss: 2.3712
# Epoch 4/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 3.5725Epoch 00003: saving model to models/audio-03-1.95.hdf5
# 39994/39994 [==============================] - 56s - loss: 3.5719 - val_loss: 1.9495
# Epoch 5/500
# 39994/39994 [==============================] - 56s - loss: 3.2637 - val_loss: 2.0702
# Epoch 6/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 3.1135Epoch 00005: saving model to models/audio-05-1.92.hdf5
# 39994/39994 [==============================] - 56s - loss: 3.1134 - val_loss: 1.9165
# Epoch 7/500
# 39994/39994 [==============================] - 56s - loss: 3.0164 - val_loss: 1.6071
# Epoch 8/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.9435Epoch 00007: saving model to models/audio-07-1.66.hdf5
# 39994/39994 [==============================] - 57s - loss: 2.9434 - val_loss: 1.6578
# Epoch 9/500
# 39994/39994 [==============================] - 56s - loss: 2.8905 - val_loss: 1.7256
# Epoch 10/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.8470Epoch 00009: saving model to models/audio-09-2.64.hdf5
# 39994/39994 [==============================] - 57s - loss: 2.8472 - val_loss: 2.6416
# Epoch 11/500
# 39994/39994 [==============================] - 56s - loss: 2.7993 - val_loss: 1.6617
# Epoch 12/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.7616Epoch 00011: saving model to models/audio-11-1.69.hdf5
# 39994/39994 [==============================] - 56s - loss: 2.7617 - val_loss: 1.6906
# Epoch 13/500
# 39994/39994 [==============================] - 56s - loss: 2.7397 - val_loss: 1.5817
# Epoch 14/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.7196Epoch 00013: saving model to models/audio-13-1.38.hdf5
# 39994/39994 [==============================] - 56s - loss: 2.7192 - val_loss: 1.3806
# Epoch 15/500
# 39994/39994 [==============================] - 56s - loss: 4.0928 - val_loss: 3.0655
# Epoch 16/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 3.0419Epoch 00015: saving model to models/audio-15-1.66.hdf5
# 39994/39994 [==============================] - 56s - loss: 3.0415 - val_loss: 1.6603
# Epoch 17/500
# 39994/39994 [==============================] - 55s - loss: 2.7342 - val_loss: 1.4393
# Epoch 18/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.6861Epoch 00017: saving model to models/audio-17-1.52.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.6863 - val_loss: 1.5228
# Epoch 19/500
# 39994/39994 [==============================] - 56s - loss: 2.6669 - val_loss: 1.4087
# Epoch 20/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.6390Epoch 00019: saving model to models/audio-19-1.48.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.6393 - val_loss: 1.4817
# Epoch 21/500
# 39994/39994 [==============================] - 55s - loss: 2.6217 - val_loss: 1.4601
# Epoch 22/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.6058Epoch 00021: saving model to models/audio-21-1.47.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.6058 - val_loss: 1.4680
# Epoch 23/500
# 39994/39994 [==============================] - 55s - loss: 2.5807 - val_loss: 1.3446
# Epoch 24/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.5715Epoch 00023: saving model to models/audio-23-1.48.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.5716 - val_loss: 1.4822
# Epoch 25/500
# 39994/39994 [==============================] - 55s - loss: 2.5488 - val_loss: 1.6489
# Epoch 26/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.5420Epoch 00025: saving model to models/audio-25-1.39.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.5423 - val_loss: 1.3938
# Epoch 27/500
# 39994/39994 [==============================] - 55s - loss: 2.5239 - val_loss: 1.2896
# Epoch 28/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.5070Epoch 00027: saving model to models/audio-27-1.43.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.5073 - val_loss: 1.4272
# Epoch 29/500
# 39994/39994 [==============================] - 55s - loss: 2.5021 - val_loss: 1.3373
# Epoch 30/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.4904Epoch 00029: saving model to models/audio-29-1.41.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.4908 - val_loss: 1.4085
# Epoch 31/500
# 39994/39994 [==============================] - 55s - loss: 2.4786 - val_loss: 1.3258
# Epoch 32/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.4648Epoch 00031: saving model to models/audio-31-1.53.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.4645 - val_loss: 1.5299
# Epoch 33/500
# 39994/39994 [==============================] - 55s - loss: 2.4498 - val_loss: 1.4416
# Epoch 34/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.4465Epoch 00033: saving model to models/audio-33-1.35.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.4464 - val_loss: 1.3500
# Epoch 35/500
# 39994/39994 [==============================] - 55s - loss: 2.4432 - val_loss: 1.3073
# Epoch 36/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.4283Epoch 00035: saving model to models/audio-35-1.34.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.4288 - val_loss: 1.3436
# Epoch 37/500
# 39994/39994 [==============================] - 55s - loss: 2.4221 - val_loss: 1.4027
# Epoch 38/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.4176Epoch 00037: saving model to models/audio-37-1.28.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.4172 - val_loss: 1.2818
# Epoch 39/500
# 39994/39994 [==============================] - 55s - loss: 2.4020 - val_loss: 1.3057
# Epoch 40/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3995Epoch 00039: saving model to models/audio-39-1.36.hdf5
# 39994/39994 [==============================] - 54s - loss: 2.3997 - val_loss: 1.3594
# Epoch 41/500
# 39994/39994 [==============================] - 55s - loss: 2.3929 - val_loss: 1.4163
# Epoch 42/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3910Epoch 00041: saving model to models/audio-41-1.40.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.3912 - val_loss: 1.3971
# Epoch 43/500
# 39994/39994 [==============================] - 55s - loss: 2.3788 - val_loss: 1.2567
# Epoch 44/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3734Epoch 00043: saving model to models/audio-43-1.20.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.3734 - val_loss: 1.1990
# Epoch 45/500
# 39994/39994 [==============================] - 55s - loss: 2.3633 - val_loss: 1.2645
# Epoch 46/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3588Epoch 00045: saving model to models/audio-45-1.37.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.3588 - val_loss: 1.3688
# Epoch 47/500
# 39994/39994 [==============================] - 55s - loss: 2.3564 - val_loss: 1.2541
# Epoch 48/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3396Epoch 00047: saving model to models/audio-47-1.16.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.3397 - val_loss: 1.1595
# Epoch 49/500
# 39994/39994 [==============================] - 55s - loss: 2.3438 - val_loss: 1.1518
# Epoch 50/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3305Epoch 00049: saving model to models/audio-49-1.26.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.3304 - val_loss: 1.2632
# Epoch 51/500
# 39994/39994 [==============================] - 55s - loss: 2.3356 - val_loss: 1.3303
# Epoch 52/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3309Epoch 00051: saving model to models/audio-51-1.36.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.3307 - val_loss: 1.3608
# Epoch 53/500
# 39994/39994 [==============================] - 55s - loss: 2.3222 - val_loss: 1.1826
# Epoch 54/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3188Epoch 00053: saving model to models/audio-53-1.30.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.3191 - val_loss: 1.2965
# Epoch 55/500
# 39994/39994 [==============================] - 55s - loss: 2.3142 - val_loss: 1.2129
# Epoch 56/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.3176Epoch 00055: saving model to models/audio-55-1.25.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.3177 - val_loss: 1.2468
# Epoch 57/500
# 39994/39994 [==============================] - 55s - loss: 2.3011 - val_loss: 1.2214
# Epoch 58/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.2959Epoch 00057: saving model to models/audio-57-1.37.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.2961 - val_loss: 1.3706
# Epoch 59/500
# 39994/39994 [==============================] - 55s - loss: 2.2994 - val_loss: 1.2048
# Epoch 60/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.2963Epoch 00059: saving model to models/audio-59-1.20.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.2963 - val_loss: 1.1955
# Epoch 61/500
# 39994/39994 [==============================] - 54s - loss: 2.2897 - val_loss: 1.3861
# Epoch 62/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.2799Epoch 00061: saving model to models/audio-61-1.25.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.2798 - val_loss: 1.2459
# Epoch 63/500
# 39994/39994 [==============================] - 55s - loss: 2.2833 - val_loss: 1.3115
# Epoch 64/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.2756Epoch 00063: saving model to models/audio-63-1.33.hdf5
# 39994/39994 [==============================] - 54s - loss: 2.2759 - val_loss: 1.3295
# Epoch 65/500
# 39994/39994 [==============================] - 54s - loss: 2.2652 - val_loss: 1.2522
# Epoch 66/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.2108Epoch 00065: saving model to models/audio-65-1.28.hdf5
# 39994/39994 [==============================] - 55s - loss: 2.2110 - val_loss: 1.2846
# Epoch 67/500
# 39994/39994 [==============================] - 54s - loss: 2.1833 - val_loss: 1.2614
# Epoch 68/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.2371Epoch 00067: saving model to models/audio-67-1.18.hdf5
# 39994/39994 [==============================] - 53s - loss: 2.2376 - val_loss: 1.1841
# Epoch 69/500
# 39994/39994 [==============================] - 54s - loss: 2.2679 - val_loss: 1.5417
# Epoch 70/500
# 39936/39994 [============================>.] - ETA: 0s - loss: 2.2729Epoch 00069: saving model to models/audio-69-2.11.hdf5
# 39994/39994 [==============================] - 54s - loss: 2.2733 - val_loss: 2.1051
# Epoch 00069: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print "Training history"
fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(1, 2, 1)
plt.plot(model.history.history['loss'])
ax1.set_title('loss')
ax2 = fig.add_subplot(1, 2, 2)
plt.plot(model.history.history['val_loss'])
ax2.set_title('validation loss')
# Out:
# Training history

# %%
# load array to audio buffer and play!!
from IPython.display import Audio, display
    
def sample(preds, temperature=1.0, min_value=0, max_value=1):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    v = np.argmax(probas)/float(probas.shape[1])
    return v * (max_value - min_value) + min_value
     
for start in range(5000,220000,10000):
    seq = y[start: maxlen]  
    seq_matrix = np.zeros((maxlen, nb_output), dtype=bool) 
    for i,s in enumerate(seq):
        sample_ = int(s * (nb_output - 1)) # 0-255
        seq_matrix[i, sample_] = True

    for i in tqdm(range(5000)):
        z = model.predict(seq_matrix.reshape((1,maxlen,nb_output)))
        s = sample(z[0], 1.0)
        seq = np.append(seq, s)

        sample_ = int(s * (nb_output - 1))    
        seq_vec = np.zeros(nb_output, dtype=bool)
        seq_vec[sample_] = True

        seq_matrix = np.vstack((seq_matrix, seq_vec))  # added generated note info 
        seq_matrix = seq_matrix[1:]
        
    # scale back 
    seq = seq * (max_y - min_y) + min_y

    # plot
    plt.figure(figsize=(30,5))
    plt.plot(seq.transpose())
    plt.show()
    
    display(Audio(seq, rate=sr))
# Out:
# 100%|██████████| 5000/5000 [04:55<00:00, 16.74it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:56<00:00, 17.14it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.05it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.65it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:52<00:00, 16.63it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.35it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:50<00:00, 17.82it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.79it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.28it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.13it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:52<00:00, 17.76it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:52<00:00, 16.89it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:52<00:00, 16.61it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.48it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:53<00:00, 17.01it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:52<00:00, 16.69it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 18.11it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:52<00:00, 17.11it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.17it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:51<00:00, 17.97it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:52<00:00, 17.00it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 100%|██████████| 5000/5000 [04:52<00:00, 17.07it/s]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# scale back 
seq = seq * (max_y - min_y) + min_y

# plot
fig = plt.figure(figsize=(30,10))
ax1 = fig.add_subplot(2, 1, 1)
plt.plot(seq.transpose())

ax2 = fig.add_subplot(2, 1, 2)
plt.plot(seq[:300].transpose())
plt.show()

# load array to audio buffer and play!!
from IPython.display import Audio, display
display(Audio(seq, rate=sr))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
